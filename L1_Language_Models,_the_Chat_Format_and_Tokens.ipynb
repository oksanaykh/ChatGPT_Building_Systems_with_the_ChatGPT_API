# %% [markdown]
# # L1 Language Models, the Chat Format and Tokens
#
# ## Setup
# #### Load the API key and relevant Python libaries.

# %%
import os
from dotenv import load_dotenv, find_dotenv
from openai import OpenAI
import tiktoken


load_dotenv(find_dotenv())

client = OpenAI()

def get_completion(prompt, model="gpt-4.1"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %% [markdown]
# ## Prompt the model and get a completion

# %%
response = get_completion("What is the capital of France?")

# %%
print(response)
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# ## Tokens

# %%
response = get_completion("Take the letters in lollipop \
and reverse them")
print(response)
# Out:
# The word **lollipop** reversed is **popillol**.

# %%
response = get_completion("""Take the letters in \
l-o-l-l-i-p-o-p and reverse them""")

# %%
print(response)
# Out:
# Sure! The word "lollipop" has the letters: l-o-l-l-i-p-o-p.
#
# Reversed, the letters are: p-o-p-i-l-l-o-l
#
# So, "lollipop" reversed is: **popillol**

# %% [markdown]
# ## Helper function (chat format)
# Here's the helper function I'll use in this course.

# %%
def get_completion_from_messages(
    messages,
    model="gpt-4.1-mini",
    temperature=0,
    max_tokens=500
):
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens
    )
    
    return response.choices[0].message.content

# %%
messages =  [  
{'role':'system', 
 'content':"""You are an assistant who\
 responds in the style of Dr Seuss."""},    
{'role':'user', 
 'content':"""write me a very short poem\
 about a happy carrot"""},  
] 
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Oh, the happy little carrot, so bright and so neat,
# With a smile on its face and small leafy feet!
# It danced in the garden, all orange and sweet,
# A jolly good veggie, a healthy green treat!

# %%
# length
messages =  [  
{'role':'system',
 'content':'All your responses must be \
one sentence long.'},    
{'role':'user',
 'content':'write me a story about a happy carrot'},  
] 
response = get_completion_from_messages(messages, temperature =1)
print(response)
# Out:
# A happy carrot named Crisp lived in a sunny garden, always smiling as it grew tall and bright, making everyone around it feel joyful.

# %%
# combined
messages =  [  
{'role':'system',
 'content':"""You are an assistant who \
responds in the style of Dr Seuss. \
All your responses must be one sentence long."""},    
{'role':'user',
 'content':"""write me a story about a happy carrot"""},
] 
response = get_completion_from_messages(messages, 
                                        temperature =1)
print(response)
# Out:
# In a bright sunny patch, the happy carrot did dance, with a wiggle and jiggle, it sang in delight, "Oh what a grand sight!"

# %%
def get_completion_and_token_count(
    messages,
    model="gpt-4.1-mini",
    temperature=0,
    max_tokens=500
):

    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens,
    )

    content = response.choices[0].message.content

    token_dict = {
        "prompt_tokens": response.usage.prompt_tokens,
        "completion_tokens": response.usage.completion_tokens,
        "total_tokens": response.usage.total_tokens,
    }

    return content, token_dict

# %%
messages = [
{'role':'system', 
 'content':"""You are an assistant who responds\
 in the style of Dr Seuss."""},    
{'role':'user',
 'content':"""write me a very short poem \ 
 about a happy carrot"""},  
] 
response, token_dict = get_completion_and_token_count(messages)

# %%
print(response)
# Out:
# Oh, the happy carrot, orange and bright,
# Dances in the garden from morning to night!
# With a hop and a skip, it wiggles with glee,
# “I’m the happiest carrot you’ll ever see!”

# %%
print(token_dict)
# Out:
# {'prompt_tokens': 37, 'completion_tokens': 47, 'total_tokens': 84}
